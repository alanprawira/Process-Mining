# %%
# !pip install pm4py

# %%
import pm4py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Log

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
ocel = pm4py.read_ocel_json('/content/drive/MyDrive/BPIC17.jsonocel')

# %%
ocel

# %%
model = pm4py.discover_oc_petri_net(ocel)

# %%
print(ocel.get_extended_table())

# %%
pm4py.view_ocpn(model)

# %%
flatten_application   = pm4py.ocel_flattening(ocel, "Application")

flatten_case_r   = pm4py.ocel_flattening(ocel, "Case_R")

flatten_workflow = pm4py.ocel_flattening(ocel, "Workflow")

flatten_offer = pm4py.ocel_flattening(ocel, "Offer")

flatten_resource = pm4py.ocel_flattening(ocel, "resource")

# %%
net, initial, final = pm4py.discovery.discover_petri_net_inductive(flatten_application)
pm4py.vis.view_petri_net(net, initial, final)

net, initial, final = pm4py.discovery.discover_petri_net_inductive(flatten_workflow)
pm4py.vis.view_petri_net(net, initial, final)

net, initial, final = pm4py.discovery.discover_petri_net_inductive(flatten_offer)
pm4py.vis.view_petri_net(net, initial, final)

net, initial, final = pm4py.discovery.discover_petri_net_inductive(flatten_case_r)
pm4py.vis.view_petri_net(net, initial, final)

net, initial, final = pm4py.discovery.discover_petri_net_inductive(flatten_resource)
pm4py.vis.view_petri_net(net, initial, final)
